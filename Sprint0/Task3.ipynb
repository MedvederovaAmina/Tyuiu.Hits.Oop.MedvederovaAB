// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания 11

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Создать базовый класс Customer в C#, который будет представлять информацию о
// клиентах или покупателях. На основе этого класса разработать 2-3 производных
// класса, демонстрирующих принципы наследования и полиморфизма. В каждом из
// классов должны быть реализованы новые атрибуты и методы, а также
// переопределены некоторые методы базового класса для демонстрации
// полиморфизма.
//
// Требования к базовому классу Customer:
//
// • Атрибуты: Идентификатор клиента (CustomerId), Имя (Name), Электронная
// почта (Email).
//
// • Методы:
// o
// o GetFullName(): метод для получения полного имени клиента.
// o UpdateEmail(string newEmail): метод для обновления электронной
// почты клиента.
// o ViewProfile(): метод для просмотра профиля клиента.
// Требования к производным классам:
// 1. VIPКлиент (VipCustomer): Должен содержать дополнительные атрибуты,
// такие как Баланс лояльности (LoyaltyPoints). Метод ViewProfile() должен быть
// переопределен для отображения дополнительной информации о VIPклиенте.
// 2. ОбычныйКлиент (RegularCustomer): Должен содержать дополнительные
// атрибуты, такие как Дата регистрации (RegistrationDate).
// Метод UpdateEmail() должен быть переопределен для добавления
// информации о дате последнего обновления электронной почты.
// 3. ГрупповойКлиент (GroupCustomer) (если требуется третий класс): Должен
// содержать дополнительные атрибуты, такие как Название группы
// (GroupName). Метод GetFullName() должен быть переопределен для
// отображения названия группы вместо имени клиента.

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public class Customer
{
    public string CustomerId { get; protected set; }
    public string Name { get; protected set; }
    public string Email { get; protected set; }

    public Customer(string customerId, string name, string email)
    {
        CustomerId = customerId;
        Name = name;
        Email = email;
    }

    public virtual string GetFullName()
    {
        return Name;
    }

    public virtual void UpdateEmail(string newEmail)
    {
        Email = newEmail;
        Console.WriteLine($"Email обновлен: {Email}");
    }

    public virtual void ViewProfile()
    {
        Console.WriteLine($"Клиент: {GetFullName()}, ID: {CustomerId}, Email: {Email}");
    }
}

public class VipCustomer : Customer
{
    public int LoyaltyPoints { get; private set; }

    public VipCustomer(string customerId, string name, string email, int loyaltyPoints)
        : base(customerId, name, email)
    {
        LoyaltyPoints = loyaltyPoints;
    }

    public override void ViewProfile()
    {
        Console.WriteLine($"VIP Клиент: {GetFullName()}, ID: {CustomerId}, Email: {Email}");
        Console.WriteLine($"Баллы лояльности: {LoyaltyPoints}, Статус: VIP");
    }
}

public class RegularCustomer : Customer
{
    public DateTime RegistrationDate { get; private set; }

    public RegularCustomer(string customerId, string name, string email, DateTime registrationDate)
        : base(customerId, name, email)
    {
        RegistrationDate = registrationDate;
    }

    public override void UpdateEmail(string newEmail)
    {
        base.UpdateEmail(newEmail);
        Console.WriteLine($"Дата обновления email: {DateTime.Now:dd.MM.yyyy HH:mm}");
    }

    public override void ViewProfile()
    {
        Console.WriteLine($"Обычный клиент: {GetFullName()}, ID: {CustomerId}, Email: {Email}");
        Console.WriteLine($"Дата регистрации: {RegistrationDate:dd.MM.yyyy}");
    }
}

public class GroupCustomer : Customer
{
    public string GroupName { get; private set; }
    public int MemberCount { get; private set; }

    public GroupCustomer(string customerId, string groupName, string email, int memberCount)
        : base(customerId, groupName, email)
    {
        GroupName = groupName;
        MemberCount = memberCount;
    }

    public override string GetFullName()
    {
        return $"Группа: {GroupName}";
    }

    public override void ViewProfile()
    {
        Console.WriteLine($"Групповой клиент: {GroupName}, ID: {CustomerId}, Email: {Email}");
        Console.WriteLine($"Количество участников: {MemberCount}");
    }
}

// Демонстрация работы
var customers = new List<Customer>
{
    new Customer("CUST-001", "Иван Иванов", "ivan@mail.com"),
    new VipCustomer("VIP-001", "Петр Петров", "petr@mail.com", 1500),
    new RegularCustomer("REG-001", "Мария Сидорова", "maria@mail.com", new DateTime(2023, 1, 15)),
    new GroupCustomer("GRP-001", "ТехноКомпания", "tech@company.com", 5)
};

foreach (var customer in customers)
{
    Console.WriteLine(customer.GetType().Name);
    customer.ViewProfile();
    customer.UpdateEmail("newemail@example.com");
    Console.WriteLine();
}
// Out:
// Customer
// Клиент: Иван Иванов, ID: CUST-001, Email: ivan@mail.com
// Email обновлен: newemail@example.com
//
// VipCustomer
// VIP Клиент: Петр Петров, ID: VIP-001, Email: petr@mail.com
// Баллы лояльности: 1500, Статус: VIP
// Email обновлен: newemail@example.com
//
// RegularCustomer
// Обычный клиент: Мария Сидорова, ID: REG-001, Email: maria@mail.com
// Дата регистрации: 15.01.2023
// Email обновлен: newemail@example.com
// Дата обновления email: 24.11.2025 16:34
//
// GroupCustomer
// Групповой клиент: ТехноКомпания, ID: GRP-001, Email: tech@company.com
// Количество участников: 5
// Email обновлен: newemail@example.com
